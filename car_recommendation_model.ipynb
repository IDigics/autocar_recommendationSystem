# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import joblib

# %%
df = pd.read_csv("cars_dataset.csv", sep=",")
df
# Out:
#       id  milage          brand              model      fuel       gear  \
# 0      1   25699  Mercedes-Benz              V 250    Diesel  Automatic
# 1      2   33572          Volvo  V90 Cross Country    Diesel  Automatic
# 2      3   12500          Mazda                  3  Gasoline  Automatic
# 3      4   29750            BMW                320    Diesel  Automatic
# 4      5   99121        Peugeot                206  Gasoline     Manual
# ..   ...     ...            ...                ...       ...        ...
# 395  396   98000          Skoda    Rapid/Spaceback  Gasoline  Automatic
# 396  397   58000      Chevrolet              Spark  Gasoline     Manual
# 397  398   10572           Opel              Corsa  Gasoline     Manual
# 398  399   25699  Mercedes-Benz              V 250    Diesel  Automatic
# 399  400   24950           Ford             Ka/Ka+  Gasoline     Manual
#
#           offerType  price  horse power  year  engine size  doors  seats  \
# 0    Employee's car  63336        190.0  2020          2.5      4      4
# 1              Used  31995        190.0  2018          4.8      4      4
# 2              Used  26990        179.0  2019          3.9      4      4
# 3              Used  38900        190.0  2019          3.4      4      4
# 4              Used   3999         60.0  2011          1.6      4      4
# ..              ...    ...          ...   ...          ...    ...    ...
# 395            Used   8990         90.0  2017          2.2      2      4
# 396            Used   3600         68.0  2013          2.4      4      4
# 397  Employee's car  13490         75.0  2020          3.3      4      2
# 398  Employee's car  63336        190.0  2020          2.5      4      4
# 399            Used   4990         69.0  2011          4.6      2      4
#
#      previous owner   color    category                      image url
# 0                 2  Silver      Luxury  https://example.com/image.jpg
# 1                 2   White      Pickup  https://example.com/image.jpg
# 2                 3   Black   Hatchback  https://example.com/image.jpg
# 3                 1    Gray      Luxury  https://example.com/image.jpg
# 4                 3   Black  Sports Car  https://example.com/image.jpg
# ..              ...     ...         ...                            ...
# 395               0    Blue  Sports Car  https://example.com/image.jpg
# 396               3   Black       Sedan  https://example.com/image.jpg
# 397               0     Red   Hatchback  https://example.com/image.jpg
# 398               2  Silver      Luxury  https://example.com/image.jpg
# 399               1   Green   Hatchback  https://example.com/image.jpg
#
# [400 rows x 17 columns]

# %%
# 1: Loading and preparing data


car_ids = df["id"].values
df_features = df.drop(columns=["id", "image url", "offerType"], errors='ignore')

categorical_cols = ["brand", "model", "gear", "fuel", "color", "category"]
numeric_cols = ["milage", "price", "horse power", "year", "engine size", "doors", "seats", "previous owner"]

# %%
# 2: Creating and preprocessing pipelines

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer(transformers=[
    ("num", numeric_transformer, numeric_cols),
    ("cat", categorical_transformer, categorical_cols)
])

# %%
# 3: Transforming features

X = preprocessor.fit_transform(df_features)

# %%
df_features
# Out:
#      milage          brand              model      fuel       gear  price  \
# 0     25699  Mercedes-Benz              V 250    Diesel  Automatic  63336
# 1     33572          Volvo  V90 Cross Country    Diesel  Automatic  31995
# 2     12500          Mazda                  3  Gasoline  Automatic  26990
# 3     29750            BMW                320    Diesel  Automatic  38900
# 4     99121        Peugeot                206  Gasoline     Manual   3999
# ..      ...            ...                ...       ...        ...    ...
# 395   98000          Skoda    Rapid/Spaceback  Gasoline  Automatic   8990
# 396   58000      Chevrolet              Spark  Gasoline     Manual   3600
# 397   10572           Opel              Corsa  Gasoline     Manual  13490
# 398   25699  Mercedes-Benz              V 250    Diesel  Automatic  63336
# 399   24950           Ford             Ka/Ka+  Gasoline     Manual   4990
#
#      horse power  year  engine size  doors  seats  previous owner   color  \
# 0          190.0  2020          2.5      4      4               2  Silver
# 1          190.0  2018          4.8      4      4               2   White
# 2          179.0  2019          3.9      4      4               3   Black
# 3          190.0  2019          3.4      4      4               1    Gray
# 4           60.0  2011          1.6      4      4               3   Black
# ..           ...   ...          ...    ...    ...             ...     ...
# 395         90.0  2017          2.2      2      4               0    Blue
# 396         68.0  2013          2.4      4      4               3   Black
# 397         75.0  2020          3.3      4      2               0     Red
# 398        190.0  2020          2.5      4      4               2  Silver
# 399         69.0  2011          4.6      2      4               1   Green
#
#        category
# 0        Luxury
# 1        Pickup
# 2     Hatchback
# 3        Luxury
# 4    Sports Car
# ..          ...
# 395  Sports Car
# 396       Sedan
# 397   Hatchback
# 398      Luxury
# 399   Hatchback
#
# [400 rows x 14 columns]

# %%
# 4: Training KNN model

knn = NearestNeighbors(metric="cosine", algorithm="brute")
knn.fit(X)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# 5: Creating recommendation function


index_to_id = {i: car_ids[i] for i in range(len(car_ids))}
id_to_index = {car_ids[i]: i for i in range(len(car_ids))}

def recommend_similar(car_id: int, n: int = 3) -> list:
    if car_id not in id_to_index:
        raise ValueError(f"Car ID {car_id} not found in the dataset.")
    
    idx = id_to_index[car_id]
    query_vector = X[idx].reshape(1, -1)
    distances, indices = knn.kneighbors(query_vector, n_neighbors=n+1) 

    similar_ids = []
    for i in indices[0]:
        if i != idx:
            similar_ids.append(int(index_to_id[i]))
        if len(similar_ids) == n:
            break

    return similar_ids

# %%
# 6: Testing

df[df["id"].isin(recommend_similar(7, n=3))]
# Out:
#       id  milage  brand   model      fuel    gear offerType  price  \
# 148  149   53473   Opel    Adam  Gasoline  Manual      Used   7800
# 155  156   90362  Skoda  Citigo  Gasoline  Manual      Used   6350
# 386  387   90362  Skoda  Citigo  Gasoline  Manual      Used   6350
#
#      horse power  year  engine size  doors  seats  previous owner  color  \
# 148         69.0  2015          1.2      2      2               1  White
# 155         75.0  2016          2.0      2      2               3   Blue
# 386         75.0  2016          2.0      2      2               3   Blue
#
#       category                      image url
# 148  Hatchback  https://example.com/image.jpg
# 155      Sedan  https://example.com/image.jpg
# 386      Sedan  https://example.com/image.jpg

# %%
# 7: Save model and pipeline

joblib.dump(knn, "car_knn_model.joblib")
joblib.dump(preprocessor, "car_preprocessor.joblib")
joblib.dump(car_ids, "car_ids.joblib")
# Out:
# ['car_ids.joblib']
